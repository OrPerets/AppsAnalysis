# %%
import pandas as pd
import numpy as np
from functions import *

# %%
# Out:
#                            _id                                 App Name  \
# 0     62e4e089a678ff0a307e6280                              英単語記憶術(中学生）
# 1     62e4e089a678ff0a307e6283                             RADIO ACCION
# 2     62e4e089a678ff0a307e6284                     أدعية للمريض بالشفاء
# 3     62e4e089a678ff0a307e6285                   Teddy Bear, I Love You
# 4     62e4e089a678ff0a307e6286                     Mufatish Report (ZU)
# ...                        ...                                      ...
# 4995  62e4e0dc41d943e3532fffd1                          Jasper Ventures
# 4996  62e4e0dc41d943e3532fffd2  Router Setup Page - WiFi Password Setup
# 4997  62e4e0dc41d943e3532fffd3                          Stickman juggle
# 4998  62e4e0dc41d943e3532fffd4           Paleo Diet Guide - Primal Eats
# 4999  62e4e0dc41d943e3532fffd5                          Feter Lifestyle
#
#                                        App Id           Category  Rating  \
# ...
